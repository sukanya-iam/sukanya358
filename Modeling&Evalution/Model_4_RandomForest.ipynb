# %%
# %pip install google-cloud
# %pip install pandas
# %pip install -U scikit-learn

from sklearn import metrics
from sklearn.metrics import confusion_matrix, plot_confusion_matrix,classification_report

from sklearn.ensemble import RandomForestClassifier

import math
from pprint import pprint
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import storage
df_train = pd.read_csv('gs://sukanya358/traindata.csv')
df_test = pd.read_csv('gs://sukanya358/testdata.csv')

# %%
y_train = df_train['y']
y_test = df_test['y']

X_train_1 = df_train[['duration']]
X_train_2 = df_train[['duration','poutcome']]
X_train_3 = df_train[['duration','poutcome','contact']]
X_train_4 = df_train[['duration','poutcome','contact','housing']]
X_train_5 = df_train[['duration','poutcome','contact','housing','pdays']]
X_train_6 = df_train[['duration','poutcome','contact','housing','pdays','previous']]
X_train_7 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_train_8 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_train_9 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]
X_test_1 = df_test[['duration']]
X_test_2 = df_test[['duration','poutcome']]
X_test_3 = df_test[['duration','poutcome','contact']]
X_test_4 = df_test[['duration','poutcome','contact','housing']]
X_test_5 = df_test[['duration','poutcome','contact','housing','pdays']]
X_test_6 = df_test[['duration','poutcome','contact','housing','pdays','previous']]
X_test_7 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_test_8 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_test_9 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]

# %%
model_4 = RandomForestClassifier()

# %%
model_4.fit(X_train_1, y_train)
model_4.score(X_train_1, y_train)
# Out:
# 0.8991838269447701

# %%
plot_confusion_matrix(model_4, X_test_1, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_1))
# Out:
# 0.8998009289980093

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      4000
#            1       0.67      0.25      0.37       521
#
#     accuracy                           0.90      4521
#    macro avg       0.79      0.62      0.66      4521
# weighted avg       0.88      0.90      0.88      4521

# %%
model_4.fit(X_train_2, y_train)
model_4.score(X_train_2, y_train)
# Out:
# 0.9185154055428989

# %%
plot_confusion_matrix(model_4, X_test_2, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_2))
# Out:
# 0.9192656491926565

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_2)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      4000
#            1       0.77      0.43      0.55       521
#
#     accuracy                           0.92      4521
#    macro avg       0.85      0.71      0.75      4521
# weighted avg       0.91      0.92      0.91      4521

# %%
model_4.fit(X_train_3, y_train)
model_4.score(X_train_3, y_train)
# Out:
# 0.926124173320652

# %%
plot_confusion_matrix(model_4, X_test_3, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_3))
# Out:
# 0.9287768192877682

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_3)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      4000
#            1       0.82      0.49      0.61       521
#
#     accuracy                           0.93      4521
#    macro avg       0.88      0.74      0.79      4521
# weighted avg       0.92      0.93      0.92      4521

# %%
model_4.fit(X_train_4, y_train)
model_4.score(X_train_4, y_train)
# Out:
# 0.9366525845480083

# %%
plot_confusion_matrix(model_4, X_test_4, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_4))
# Out:
# 0.9376244193762442

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_4)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      4000
#            1       0.87      0.54      0.67       521
#
#     accuracy                           0.94      4521
#    macro avg       0.91      0.77      0.82      4521
# weighted avg       0.93      0.94      0.93      4521

# %%
model_4.fit(X_train_5, y_train)
model_4.score(X_train_5, y_train)
# Out:
# 0.9502112317798765

# %%
plot_confusion_matrix(model_4, X_test_5, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_5))
# Out:
# 0.9508958195089582

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_5)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4000
#            1       0.92      0.63      0.75       521
#
#     accuracy                           0.95      4521
#    macro avg       0.94      0.81      0.86      4521
# weighted avg       0.95      0.95      0.95      4521

# %%
model_4.fit(X_train_6, y_train)
model_4.score(X_train_6, y_train)
# Out:
# 0.9504102983787132

# %%
plot_confusion_matrix(model_4, X_test_6, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_6))
# Out:
# 0.9497898694978987

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_6)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4000
#            1       0.91      0.63      0.74       521
#
#     accuracy                           0.95      4521
#    macro avg       0.93      0.81      0.86      4521
# weighted avg       0.95      0.95      0.95      4521

# %%
model_4.fit(X_train_7, y_train)
model_4.score(X_train_7, y_train)
# Out:
# 0.9654730043573466

# %%
plot_confusion_matrix(model_4, X_test_7, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_7))
# Out:
# 0.9694757796947578

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_7)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      4000
#            1       0.96      0.77      0.85       521
#
#     accuracy                           0.97      4521
#    macro avg       0.96      0.88      0.92      4521
# weighted avg       0.97      0.97      0.97      4521

# %%
model_4.fit(X_train_8, y_train)
model_4.score(X_train_8, y_train)
# Out:
# 0.9686138329167681

# %%
plot_confusion_matrix(model_4, X_test_8, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_8))
# Out:
# 0.9703605397036054

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_8)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4000
#            1       0.94      0.79      0.86       521
#
#     accuracy                           0.97      4521
#    macro avg       0.96      0.89      0.92      4521
# weighted avg       0.97      0.97      0.97      4521

# %%
model_4.fit(X_train_9, y_train)
model_4.score(X_train_9, y_train)
# Out:
# 0.9780363185950322

# %%
plot_confusion_matrix(model_4, X_test_9, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_4.predict(X_test_9))
# Out:
# 0.980092899800929

# %%
print(metrics.classification_report(y_test, model_4.predict(X_test_9)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4000
#            1       0.97      0.85      0.91       521
#
#     accuracy                           0.98      4521
#    macro avg       0.98      0.92      0.95      4521
# weighted avg       0.98      0.98      0.98      4521
