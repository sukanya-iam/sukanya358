# %%
# %pip install google-cloud
# %pip install pandas
# %pip install -U scikit-learn

from sklearn import metrics
from sklearn.metrics import confusion_matrix, plot_confusion_matrix,classification_report

from sklearn.neighbors import KNeighborsClassifier

import math
from pprint import pprint
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import storage
df_train = pd.read_csv('gs://sukanya358/traindata.csv')
df_test = pd.read_csv('gs://sukanya358/testdata.csv')

# %%
y_train = df_train['y']
y_test = df_test['y']

X_train_1 = df_train[['duration']]
X_train_2 = df_train[['duration','poutcome']]
X_train_3 = df_train[['duration','poutcome','contact']]
X_train_4 = df_train[['duration','poutcome','contact','housing']]
X_train_5 = df_train[['duration','poutcome','contact','housing','pdays']]
X_train_6 = df_train[['duration','poutcome','contact','housing','pdays','previous']]
X_train_7 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_train_8 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_train_9 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]
X_test_1 = df_test[['duration']]
X_test_2 = df_test[['duration','poutcome']]
X_test_3 = df_test[['duration','poutcome','contact']]
X_test_4 = df_test[['duration','poutcome','contact','housing']]
X_test_5 = df_test[['duration','poutcome','contact','housing','pdays']]
X_test_6 = df_test[['duration','poutcome','contact','housing','pdays','previous']]
X_test_7 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_test_8 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_test_9 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]

# %%
model_5 = KNeighborsClassifier(n_neighbors=1)

# %%
model_5.fit(X_train_1, y_train)
model_5.score(X_train_1, y_train)
# Out:
# 0.8536196943221782

# %%
plot_confusion_matrix(model_5, X_test_1, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_1))
# Out:
# 0.8540145985401459

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      4000
#            1       0.35      0.31      0.33       521
#
#     accuracy                           0.85      4521
#    macro avg       0.63      0.62      0.62      4521
# weighted avg       0.85      0.85      0.85      4521

# %%
model_5.fit(X_train_2, y_train)
model_5.score(X_train_2, y_train)
# Out:
# 0.8763575236115104

# %%
plot_confusion_matrix(model_5, X_test_2, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_2))
# Out:
# 0.8774607387746074

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_2)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      4000
#            1       0.47      0.48      0.47       521
#
#     accuracy                           0.88      4521
#    macro avg       0.70      0.70      0.70      4521
# weighted avg       0.88      0.88      0.88      4521

# %%
model_5.fit(X_train_3, y_train)
model_5.score(X_train_3, y_train)
# Out:
# 0.8914865851230895

# %%
plot_confusion_matrix(model_5, X_test_3, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_3))
# Out:
# 0.8911745189117452

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_3)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4000
#            1       0.53      0.54      0.53       521
#
#     accuracy                           0.89      4521
#    macro avg       0.73      0.74      0.74      4521
# weighted avg       0.89      0.89      0.89      4521

# %%
model_5.fit(X_train_4, y_train)
model_5.score(X_train_4, y_train)
# Out:
# 0.907389794519033

# %%
plot_confusion_matrix(model_5, X_test_4, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_4))
# Out:
# 0.9077637690776377

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_4)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      4000
#            1       0.59      0.64      0.61       521
#
#     accuracy                           0.91      4521
#    macro avg       0.77      0.79      0.78      4521
# weighted avg       0.91      0.91      0.91      4521

# %%
model_5.fit(X_train_5, y_train)
model_5.score(X_train_5, y_train)
# Out:
# 0.9323615934175311

# %%
plot_confusion_matrix(model_5, X_test_5, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_5))
# Out:
# 0.9365184693651847

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_5)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4000
#            1       0.73      0.71      0.72       521
#
#     accuracy                           0.94      4521
#    macro avg       0.85      0.84      0.84      4521
# weighted avg       0.94      0.94      0.94      4521

# %%
model_5.fit(X_train_6, y_train)
model_5.score(X_train_6, y_train)
# Out:
# 0.9325385415053858

# %%
plot_confusion_matrix(model_5, X_test_6, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_6))
# Out:
# 0.9365184693651847

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_6)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4000
#            1       0.73      0.71      0.72       521
#
#     accuracy                           0.94      4521
#    macro avg       0.85      0.84      0.84      4521
# weighted avg       0.94      0.94      0.94      4521

# %%
model_5.fit(X_train_7, y_train)
model_5.score(X_train_7, y_train)
# Out:
# 0.9557850965473005

# %%
plot_confusion_matrix(model_5, X_test_7, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_7))
# Out:
# 0.9619553196195532

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_7)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4000
#            1       0.84      0.83      0.83       521
#
#     accuracy                           0.96      4521
#    macro avg       0.91      0.90      0.91      4521
# weighted avg       0.96      0.96      0.96      4521

# %%
model_5.fit(X_train_8, y_train)
model_5.score(X_train_8, y_train)
# Out:
# 0.9615137908915972

# %%
plot_confusion_matrix(model_5, X_test_8, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_8))
# Out:
# 0.966821499668215

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_8)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4000
#            1       0.86      0.85      0.85       521
#
#     accuracy                           0.97      4521
#    macro avg       0.92      0.92      0.92      4521
# weighted avg       0.97      0.97      0.97      4521

# %%
model_5.fit(X_train_9, y_train)
model_5.score(X_train_9, y_train)
# Out:
# 0.9746300679038287

# %%
plot_confusion_matrix(model_5, X_test_9, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_5.predict(X_test_9))
# Out:
# 0.97788099977881

# %%
print(metrics.classification_report(y_test, model_5.predict(X_test_9)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4000
#            1       0.91      0.90      0.90       521
#
#     accuracy                           0.98      4521
#    macro avg       0.95      0.94      0.95      4521
# weighted avg       0.98      0.98      0.98      4521
