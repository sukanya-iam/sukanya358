# %%
# %pip install google-cloud
# %pip install pandas
# %pip install -U scikit-learn

from sklearn import metrics
from sklearn.metrics import confusion_matrix, plot_confusion_matrix,classification_report

# %pip install -U lightgbm
import lightgbm as lgb

import math
from pprint import pprint
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import storage
df_train = pd.read_csv('gs://sukanya358/traindata.csv')
df_test = pd.read_csv('gs://sukanya358/testdata.csv')

# %%
model_3 = lgb.LGBMClassifier()

# %%
y_train = df_train['y']
y_test = df_test['y']

X_train_1 = df_train[['duration']]
X_train_2 = df_train[['duration','poutcome']]
X_train_3 = df_train[['duration','poutcome','contact']]
X_train_4 = df_train[['duration','poutcome','contact','housing']]
X_train_5 = df_train[['duration','poutcome','contact','housing','pdays']]
X_train_6 = df_train[['duration','poutcome','contact','housing','pdays','previous']]
X_train_7 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_train_8 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_train_9 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]
X_test_1 = df_test[['duration']]
X_test_2 = df_test[['duration','poutcome']]
X_test_3 = df_test[['duration','poutcome','contact']]
X_test_4 = df_test[['duration','poutcome','contact','housing']]
X_test_5 = df_test[['duration','poutcome','contact','housing','pdays']]
X_test_6 = df_test[['duration','poutcome','contact','housing','pdays','previous']]
X_test_7 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_test_8 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_test_9 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]

# %%
model_3.fit(X_train_1, y_train)
model_3.score(X_train_1, y_train)
# Out:
# 0.8894295636017784

# %%
plot_confusion_matrix(model_3, X_test_1, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_1))
# Out:
# 0.8898473788984738

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4000
#            1       0.56      0.19      0.29       521
#
#     accuracy                           0.89      4521
#    macro avg       0.73      0.59      0.61      4521
# weighted avg       0.86      0.89      0.87      4521

# %%
model_3.fit(X_train_2, y_train)
model_3.score(X_train_2, y_train)
# Out:
# 0.9022361814602641

# %%
plot_confusion_matrix(model_3, X_test_2, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_2))
# Out:
# 0.9009068790090687

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_2)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      4000
#            1       0.63      0.34      0.44       521
#
#     accuracy                           0.90      4521
#    macro avg       0.78      0.66      0.69      4521
# weighted avg       0.89      0.90      0.89      4521

# %%
model_3.fit(X_train_3, y_train)
model_3.score(X_train_3, y_train)
# Out:
# 0.9033421070093561

# %%
plot_confusion_matrix(model_3, X_test_3, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_3))
# Out:
# 0.9042247290422473

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_3)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      4000
#            1       0.67      0.34      0.45       521
#
#     accuracy                           0.90      4521
#    macro avg       0.79      0.66      0.70      4521
# weighted avg       0.89      0.90      0.89      4521

# %%
model_3.fit(X_train_4, y_train)
model_3.score(X_train_4, y_train)
# Out:
# 0.90447015106943

# %%
plot_confusion_matrix(model_3, X_test_4, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_4))
# Out:
# 0.9059942490599425

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_4)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      4000
#            1       0.67      0.36      0.47       521
#
#     accuracy                           0.91      4521
#    macro avg       0.80      0.67      0.71      4521
# weighted avg       0.89      0.91      0.89      4521

# %%
model_3.fit(X_train_5, y_train)
model_3.score(X_train_5, y_train)
# Out:
# 0.9103315564796178

# %%
plot_confusion_matrix(model_3, X_test_5, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_5))
# Out:
# 0.9117451891174518

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_5)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4000
#            1       0.71      0.39      0.51       521
#
#     accuracy                           0.91      4521
#    macro avg       0.82      0.69      0.73      4521
# weighted avg       0.90      0.91      0.90      4521

# %%
model_3.fit(X_train_6, y_train)
model_3.score(X_train_6, y_train)
# Out:
# 0.9102430824356904

# %%
plot_confusion_matrix(model_3, X_test_6, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_6))
# Out:
# 0.9128511391285113

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_6)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4000
#            1       0.72      0.40      0.51       521
#
#     accuracy                           0.91      4521
#    macro avg       0.82      0.69      0.73      4521
# weighted avg       0.90      0.91      0.90      4521

# %%
model_3.fit(X_train_7, y_train)
model_3.score(X_train_7, y_train)
# Out:
# 0.9113268894738006

# %%
plot_confusion_matrix(model_3, X_test_7, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_7))
# Out:
# 0.9141782791417828

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_7)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4000
#            1       0.73      0.40      0.52       521
#
#     accuracy                           0.91      4521
#    macro avg       0.83      0.69      0.74      4521
# weighted avg       0.90      0.91      0.90      4521

# %%
model_3.fit(X_train_8, y_train)
model_3.score(X_train_8, y_train)
# Out:
# 0.911415363517728

# %%
plot_confusion_matrix(model_3, X_test_8, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_8))
# Out:
# 0.9128511391285113

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_8)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4000
#            1       0.72      0.40      0.51       521
#
#     accuracy                           0.91      4521
#    macro avg       0.82      0.69      0.73      4521
# weighted avg       0.90      0.91      0.90      4521

# %%
model_3.fit(X_train_9, y_train)
model_3.score(X_train_9, y_train)
# Out:
# 0.9115923116055827

# %%
plot_confusion_matrix(model_3, X_test_9, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_3.predict(X_test_9))
# Out:
# 0.9117451891174518

# %%
print(metrics.classification_report(y_test, model_3.predict(X_test_9)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4000
#            1       0.71      0.40      0.51       521
#
#     accuracy                           0.91      4521
#    macro avg       0.82      0.69      0.73      4521
# weighted avg       0.90      0.91      0.90      4521
