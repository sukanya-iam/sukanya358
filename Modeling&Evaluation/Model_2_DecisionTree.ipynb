# %%
# %pip install google-cloud
# %pip install pandas
# %pip install -U scikit-learn

from sklearn import metrics
from sklearn.metrics import confusion_matrix, plot_confusion_matrix,classification_report

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

import math
from pprint import pprint
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.20.3
#     Uninstalling scikit-learn-0.20.3:
#       Successfully uninstalled scikit-learn-0.20.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import storage
df_train = pd.read_csv('gs://sukanya358/traindata.csv')
df_test = pd.read_csv('gs://sukanya358/testdata.csv')

# %%
y_train = df_train['y']
y_test = df_test['y']

X_train_1 = df_train[['duration']]
X_train_2 = df_train[['duration','poutcome']]
X_train_3 = df_train[['duration','poutcome','contact']]
X_train_4 = df_train[['duration','poutcome','contact','housing']]
X_train_5 = df_train[['duration','poutcome','contact','housing','pdays']]
X_train_6 = df_train[['duration','poutcome','contact','housing','pdays','previous']]
X_train_7 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_train_8 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_train_9 = df_train[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]
X_test_1 = df_test[['duration']]
X_test_2 = df_test[['duration','poutcome']]
X_test_3 = df_test[['duration','poutcome','contact']]
X_test_4 = df_test[['duration','poutcome','contact','housing']]
X_test_5 = df_test[['duration','poutcome','contact','housing','pdays']]
X_test_6 = df_test[['duration','poutcome','contact','housing','pdays','previous']]
X_test_7 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign']]
X_test_8 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan']]
X_test_9 = df_test[['duration','poutcome','contact','housing','pdays','previous','campaign','loan','marital']]

# %%
model_2 = tree.DecisionTreeClassifier()

# %%
model_2.fit(X_train_1, y_train)
model_2.score(X_train_1, y_train)
# Out:
# 0.8991838269447701

# %%
plot_confusion_matrix(model_2, X_test_1, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_2.predict(X_test_1))
# Out:
# 0.9006856890068569

# %%
print(metrics.classification_report(y_test, model_2.predict(X_test_1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      4000
#            1       0.72      0.22      0.34       521
#
#     accuracy                           0.90      4521
#    macro avg       0.81      0.61      0.64      4521
# weighted avg       0.89      0.90      0.88      4521

# %%
model_2.fit(X_train_2, y_train)
model_2.score(X_train_2, y_train)
# Out:
# 0.9185154055428989

# %%
plot_confusion_matrix(model_2, X_test_2, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_2.predict(X_test_2))
# Out:
# 0.9192656491926565

# %%
print(metrics.classification_report(y_test, model_2.predict(X_test_2)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4000
#            1       0.82      0.39      0.52       521
#
#     accuracy                           0.92      4521
#    macro avg       0.87      0.69      0.74      4521
# weighted avg       0.91      0.92      0.91      4521

# %%
model_2.fit(X_train_3, y_train)
model_2.score(X_train_3, y_train)
# Out:
# 0.9261684103426158

# %%
plot_confusion_matrix(model_2, X_test_3, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_2.predict(X_test_3))
# Out:
# 0.9298827692988277

# %%
print(metrics.classification_report(y_test, model_2.predict(X_test_3)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4000
#            1       0.89      0.45      0.60       521
#
#     accuracy                           0.93      4521
#    macro avg       0.91      0.72      0.78      4521
# weighted avg       0.93      0.93      0.92      4521

# %%
model_2.fit(X_train_4, y_train)
model_2.score(X_train_4, y_train)
# Out:
# 0.93667470305899

# %%
plot_confusion_matrix(model_2, X_test_4, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_2.predict(X_test_4))
# Out:
# 0.9376244193762442

# %%
print(metrics.classification_report(y_test, model_2.predict(X_test_4)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4000
#            1       0.94      0.49      0.64       521
#
#     accuracy                           0.94      4521
#    macro avg       0.94      0.74      0.80      4521
# weighted avg       0.94      0.94      0.93      4521

# %%
model_2.fit(X_train_5, y_train)
model_2.score(X_train_5, y_train)
# Out:
# 0.9502554688018403

# %%
plot_confusion_matrix(model_2, X_test_5, y_test, cmap='Oranges', display_labels=['no','yes'])

# %%
metrics.accuracy_score(y_test, model_2.predict(X_test_5))
# Out:
# 0.9495686794956868

# %%
print(metrics.classification_report(y_test, model_2.predict(X_test_5)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4000
#            1       0.96      0.59      0.73       521
#
#     accuracy                           0.95      4521
#    macro avg       0.96      0.79      0.85      4521
# weighted avg       0.95      0.95      0.94      4521

# %%
# %pip install graphviz
# %pip install pydotplus
# %pip install --upgrade scikit-learn==0.20.3
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached scikit_learn-0.20.3-cp37-cp37m-manylinux1_x86_64.whl (5.4 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dot_data = StringIO()
export_graphviz(model_2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = X_train_5.columns, 
                class_names=['0','1'],
                max_depth=2)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
dot_data = StringIO()
export_graphviz(model_2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = X_train_5.columns, 
                class_names=['0','1'],
                max_depth=3)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
dot_data = StringIO()
export_graphviz(model_2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = X_train_5.columns, 
                class_names=['0','1'],
                max_depth=4)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
